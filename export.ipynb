# %% [markdown]
# <h1 align="center">EXPORT IMAGES</h1>

# %%
from PIL import Image
from utils import export_for_web

# %% [markdown]
# ## 1 - EXPORT FOT WEB

# %%
img = Image.open("data/automne.jpg")  # ton image finale

files = export_for_web(
    img,
    out_basename="exports/automne",     # génère exports/automne-640.webp, etc.
    widths=(480, 768, 1024, 1600),
    prefer_lossless_if_graphic=True,
    lossy_quality=82,
    jpeg_fallback=True                   # utile si tu cibles Safari très vieux / e-mail
)
print(files)
# Out:
# ['exports/automne-480.webp', 'exports/automne-480.jpg', 'exports/automne-768.webp', 'exports/automne-768.jpg', 'exports/automne-1024.webp', 'exports/automne-1024.jpg', 'exports/automne-1600.webp', 'exports/automne-1600.jpg']
